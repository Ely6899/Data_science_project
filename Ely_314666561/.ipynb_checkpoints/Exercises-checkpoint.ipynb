# %% [markdown]
# # Author: Ely Kozinets(314666561)

# %% [markdown]
# # Exercise 1 - Decimal converter

# %%
number = int(input("Enter a regular number: "))
# Out:
# Enter a regular number: 45

# %%
type(number)
# Out:
# int

# %%
#Converts a given decimal number to binary, octal and hexa forms
def decimal_converter(number):
    result_binary = ""
    result_octal = ""
    result_hexa = ""
    num1 = number
    num2 = number
    num3 = number
    original_number = number
    while(num1 != 0):
        remainder = num1 % 2;
        result_binary = str(remainder) + result_binary
        num1 = int(num1 / 2)

    while(num2 != 0):
        remainder = num2 % 8;
        result_octal = str(remainder) + result_octal
        num2 = int(num2 / 8)
        
    switch = {
                10: "A",
                11: "B",
                12: "C",
                13: "D",
                14: "E",
                15: "F"
            }
    
    while(num3 != 0):
        remainder = num3 % 16
        if(remainder >= 10 and remainder < 16):
            result_hexa = switch.get(remainder) + result_hexa
        else:
            result_hexa = str(remainder) + result_hexa
        num3 = int(num3/16)
        
    return (str(original_number) + " decimal" + " in: \n"+
            "Binary: " + result_binary + "\n"+ 
            "Octal: " + result_octal + "\n"+ 
            "Hexa: " +  result_hexa)

# %%
print(decimal_converter(number))
# Out:
# 45 decimal in:
# Binary: 101101
# Octal: 55
# Hexa: 2D

# %% [markdown]
# # Exercise 2 - Pandas questions

# %%
import pandas as pd
import matplotlib
data = pd.read_csv("cast.csv")
data.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %%
data.describe(include = 'all')
# Out:
#                                   title          year          name     type  \
# count                           3333695  3.333695e+06       3333695  3333695
# unique                           160353           NaN       1213281        2
# top     Around the World in Eighty Days           NaN  Bess Flowers    actor
# freq                               1300           NaN           808  2257021
# mean                                NaN  1.986708e+03           NaN      NaN
# std                                 NaN  2.789293e+01           NaN      NaN
# min                                 NaN  1.894000e+03           NaN      NaN
# 25%                                 NaN  1.966000e+03           NaN      NaN
# 50%                                 NaN  1.998000e+03           NaN      NaN
# 75%                                 NaN  2.010000e+03           NaN      NaN
# max                                 NaN  2.021000e+03           NaN      NaN
#
#        character             n
# ...

# %%
#1. How many movies have the title "Hamlet"?

#Answer
len(data[data.title == "Hamlet"])
# Out:
# 299

# %%
#2. List all of the "Treasure Island" movies from earliest to most recent.

#Answer
data[data.title == "Treasure Island"].sort_values(by = "year")
# Out:
#                    title  year                  name     type  \
# 1312766  Treasure Island  1918       Herschel Mayall    actor
# 3280557  Treasure Island  1918    Eleanor Washington  actress
# 3046750  Treasure Island  1918      Violet Radcliffe  actress
# 1167783  Treasure Island  1918           Raymond Lee    actor
# 1195421  Treasure Island  1918          Elmo Lincoln    actor
# ...                  ...   ...                   ...      ...
# 1663860  Treasure Island  1999  Victor Raider-Wexler    actor
# 1731182  Treasure Island  1999  Scot Thomas Robinson    actor
# 1813707  Treasure Island  1999        Richard Schave    actor
# 2710458  Treasure Island  1999    Stephanie Ittleson  actress
# 815338   Treasure Island  1999          Rio Hackford    actor
#
#                 character     n
# 1312766   Prologue Player   NaN
# 3280557   Prologue Player   NaN
# 3046750  Long John Silver   3.0
# 1167783          Bit Role   NaN
# 1195421   Prologue Player   NaN
# ...

# %%
#3. How many roles were credited in the silent 1921 version of Hamlet?

new_small_data1 = data[(data.title == "Hamlet") & (data.year == 1921)]

#Relevant data to the question.
new_small_data1
# Out:
#           title  year                    name     type         character    n
# 6710     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 408456   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 495468   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1015046  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 1948795  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2116906  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2370048  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2713980  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 2964897  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
#Answer
new_small_data1["character"].nunique()
# Out:
# 9

# %%
#4. Use groupby() to plot the number of "Hamlet" films made each decade

hamlet_data = data[data.title == "Hamlet"]
hamlet_data["decade"] = ((hamlet_data.year // 10) * 10)
hamlet_data
# Out:
# <ipython-input-67-259da11bfe4f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet_data["decade"] = ((hamlet_data.year // 10) * 10)
#           title  year              name     type              character     n  \
# 1456     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1.0
# 6710     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9.0
# 10274    Hamlet  2009      Hayden Adams    actor                Laertes   7.0
# 10275    Hamlet  2009      Hayden Adams    actor                 Player   7.0
# 12743    Hamlet  1913       Eric Adeney    actor               Reynaldo  14.0
# ...         ...   ...               ...      ...                    ...   ...
# ...

# %%
#Answer

#because a movie is released once per year, we can say it is also the number of movies released per decade.
hamlet_data.groupby("decade").nunique("year").drop(["title","name", "type", "character", "n"], axis = 1) \
.rename(columns = {"year" : "number of 'Hamlet' movies"}).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='decade'>

# %%
#5. How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

question5_data = data[(data.year >= 1950) & (data.year <= 1959) & (data.n == 1)]
#A data split of the 1950's with only leading roles.
question5_data
# Out:
#                                                     title  year  \
# 1469                                    Bir qalanin sirri  1959
# 1688                       Abbott and Costello Go to Mars  1953
# 1689            Abbott and Costello in the Foreign Legion  1950
# 1690                Abbott and Costello Meet Captain Kidd  1952
# 1691     Abbott and Costello Meet Dr. Jekyll and Mr. Hyde  1953
# ...                                                   ...   ...
# 3329729                    Mit siebzehn beginnt das Leben  1953
# 3331576                                  El vampiro negro  1953
# 3331577                                  El vampiro negro  1953
# 3331582                                         Marianela  1955
# 3331583                                         Valentina  1950
#
#                     name     type                  character    n
# 1469     Gyunduz Abbasov    actor                      Elsan  1.0
# ...

# %%
#Answer
#This answer inclues only data from the 1950's and only leading roles(n = 1).
question5_data.groupby(['year', 'type']).sum()
# Out:
#                   n
# year type
# 1950 actor    604.0
#      actress  271.0
# 1951 actor    633.0
#      actress  272.0
# 1952 actor    591.0
#      actress  284.0
# 1953 actor    634.0
#      actress  290.0
# 1954 actor    626.0
#      actress  298.0
# 1955 actor    606.0
#      actress  264.0
# 1956 actor    614.0
#      actress  288.0
# 1957 actor    708.0
#      actress  284.0
# 1958 actor    694.0
#      actress  275.0
# 1959 actor    678.0
#      actress  287.0

# %%
#6 List the 10 actors/actresses that have the most leading roles (n=1) since the 1990's.

question6_data = data[(data.year >= 1990) & (data.n == 1)]
#Data relevant to the question.
question6_data
# Out:
#                           title  year              name     type  \
# 88       Live Freaky Die Freaky  2006           Nick 13    actor
# 125       All Things Fall Apart  2011           50 Cent    actor
# 130                 Freelancers  2012           50 Cent    actor
# 131      Get Rich or Die Tryin'  2005           50 Cent    actor
# 132                         Gun  2010           50 Cent    actor
# ...                         ...   ...               ...      ...
# 3333400                     120  2008       ?zge ?zberk  actress
# 3333513                Doyumsuz  1990       Bahar ?ztan  actress
# 3333522                  Kadife  2012      Ayta? ?ztuna  actress
# 3333556              Dig og mig  2008  Julie R. ?lgaard  actress
# 3333576      Mimi og madammerne  1998         Tammi ?st  actress
#
#               character    n
# 88       TV Reporter #1  1.0
# 125                Deon  1.0
# 130                Malo  1.0
# 131              Marcus  1.0
# 132                Rich  1.0
# ...

# %%
#Answer
#This only starts from the 1990's, like required in the question.
question6_data.groupby(["name", "type"]).sum().head(10).sort_values("n", ascending = False).drop(['year'], axis = 1)
# Out:
#                                       n
# name                      type
# 'Chiyaan' Vikram          actor    25.0
# 'University' Jeevan       actor     7.0
# 50 Cent                   actor     5.0
# 2Meka Diaz                actress   2.0
# ?dgar (II) Ram?rez        actor     2.0
# 'Cowboy' Matt Hopewell    actor     1.0
# 'Pook Diesel' Paul Watson actor     1.0
# ?caro Silva               actor     1.0
# ?ce Mrozek                actor     1.0
# ?d?m Lux                  actor     1.0

# %%
#7 List, in order by year, each of the films in which Frank Oz has played more than 1 role

question7_data = data[(data.name == "Frank Oz")].sort_values("year")
#Data relevant to the question.
question7_data
# Out:
#                                                 title  year      name   type  \
# 1538820                              The Muppet Movie  1979  Frank Oz  actor
# 1538827                              The Muppet Movie  1979  Frank Oz  actor
# 1538826                              The Muppet Movie  1979  Frank Oz  actor
# 1538825                              The Muppet Movie  1979  Frank Oz  actor
# 1538824                              The Muppet Movie  1979  Frank Oz  actor
# ...                                               ...   ...       ...    ...
# 1538782                                Monsters, Inc.  2001  Frank Oz  actor
# 1538796  Star Wars: Episode II - Attack of the Clones  2002  Frank Oz  actor
# 1538797  Star Wars: Episode III - Revenge of the Sith  2005  Frank Oz  actor
# 1538836                    Zathura: A Space Adventure  2005  Frank Oz  actor
# 1538780                                    Inside Out  2015  Frank Oz  actor
#
#                         character     n
# ...

# %%
#Answer
#This only uses the relevant data from above.
question7_data.groupby(["title", "year"]) \
.nunique() \
.drop(["name", "type", "n"], axis = 1) \
.sort_values("year") \
.query('character > 1')
# Out:
#                                                character
# title                                    year
# The Muppet Movie                         1979          8
# The Great Muppet Caper                   1981          6
# An American Werewolf in London           1981          2
# The Dark Crystal                         1982          2
# The Muppets Take Manhattan               1984          7
# Sesame Street Presents: Follow that Bird 1985          3
# The Muppet Christmas Carol               1992          7
# Muppet Treasure Island                   1996          4
# Muppets from Space                       1999          4
# The Adventures of Elmo in Grouchland     1999          3
