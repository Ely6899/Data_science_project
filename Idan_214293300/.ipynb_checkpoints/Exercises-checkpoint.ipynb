# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = int(input("Enter any number: "))

to_string = {10:"A", 11:"B", 12:"C", 13:"D", 14:"E", 15:"F"}
for i in range(10):
    to_string[i] = str(i)

copy = x
for i in [2, 8, 16]:
    new_x = ""
    x = copy
    while(x != 0):
        remainder = x%i
        new_x += to_string[remainder]
        x = x//i
    print("Base " + str(i) + ": " + new_x[::-1])
# Out:
# Enter any number: 1010
# Base 2: 1111110010
# Base 8: 1762
# Base 16: 3F2

# %%
cast = pd.read_csv("cast.csv")
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %%
cast["title"].value_counts().Hamlet
# Out:
# 299

# %%
cast[cast["title"] == "Treasure Island"].sort_values(by=["year"])
# Out:
#                    title  year                  name     type  \
# 1312766  Treasure Island  1918       Herschel Mayall    actor
# 3280557  Treasure Island  1918    Eleanor Washington  actress
# 3046750  Treasure Island  1918      Violet Radcliffe  actress
# 1167783  Treasure Island  1918           Raymond Lee    actor
# 1195421  Treasure Island  1918          Elmo Lincoln    actor
# ...                  ...   ...                   ...      ...
# 1663860  Treasure Island  1999  Victor Raider-Wexler    actor
# 1731182  Treasure Island  1999  Scot Thomas Robinson    actor
# 1813707  Treasure Island  1999        Richard Schave    actor
# 2710458  Treasure Island  1999    Stephanie Ittleson  actress
# 815338   Treasure Island  1999          Rio Hackford    actor
#
#                 character     n
# 1312766   Prologue Player   NaN
# 3280557   Prologue Player   NaN
# 3046750  Long John Silver   3.0
# 1167783          Bit Role   NaN
# 1195421   Prologue Player   NaN
# ...

# %%
cast[(cast["year"] == 1921) & (cast["title"] == "Hamlet")]
# Out:
#           title  year                    name     type         character    n
# 6710     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 408456   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 495468   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1015046  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 1948795  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2116906  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2370048  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2713980  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 2964897  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
this = cast[cast["title"] == "Hamlet"].groupby("year").count()
plt.plot(this["title"])
plt.show()

# %%
cast[(cast["n"] == 1) & (cast["year"] == 1950)].groupby("type").count()["title"]
# Out:
# type
# actor      604
# actress    271
# Name: title, dtype: int64

# %%
cast[(cast["n"] == 1) & (cast["year"] >= 1990)].groupby("name").count().sort_values(by=["title"], ascending=False)["title"].head(10)
# Out:
# name
# Mohanlal              126
# Mammootty             118
# Akshay Kumar           87
# Jayaram                76
# Andy Lau               72
# Ajay Devgn             69
# Amitabh Bachchan       68
# Eric Roberts           68
# Nagarjuna Akkineni     60
# Dilip                  59
# Name: title, dtype: int64

# %%
cast[(cast["name"] == "Frank Oz") & (cast["n"] > 1)].sort_values(by=["year"])
# Out:
#                                                   title  year      name  \
# 1538820                                The Muppet Movie  1979  Frank Oz
# 1538827                                The Muppet Movie  1979  Frank Oz
# 1538826                                The Muppet Movie  1979  Frank Oz
# 1538825                                The Muppet Movie  1979  Frank Oz
# 1538824                                The Muppet Movie  1979  Frank Oz
# 1538823                                The Muppet Movie  1979  Frank Oz
# 1538822                                The Muppet Movie  1979  Frank Oz
# 1538821                                The Muppet Movie  1979  Frank Oz
# 1538804                              The Blues Brothers  1980  Frank Oz
# 1538798  Star Wars: Episode V - The Empire Strikes Back  1980  Frank Oz
# 1538812                          The Great Muppet Caper  1981  Frank Oz
# 1538811                          The Great Muppet Caper  1981  Frank Oz
# ...
