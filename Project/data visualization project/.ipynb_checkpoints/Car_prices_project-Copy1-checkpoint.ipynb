# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from warnings import filterwarnings
filterwarnings("ignore")

# %%
from warnings import simplefilter
simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# # Semester 1 part

# %% [markdown]
# # Data pre-processing, organizing and cleaning

# %%
data = pd.read_csv("Car prices.csv", sep = "|")
data
# Out:
#        semel_yevuan          shem_yevuan sug_degem  tozeret_cd  \
# 0               110  צ'מפיון מוטורס בע"מ         M         724
# 1               110  צ'מפיון מוטורס בע"מ         M         724
# 2               110  צ'מפיון מוטורס בע"מ         M         724
# 3               110  צ'מפיון מוטורס בע"מ         M         724
# 4               110  צ'מפיון מוטורס בע"מ         M         724
# ...             ...                  ...       ...         ...
# 33333           767          מיכאל ביטון         P         728
# 33334           134     קבוצת עמק איילון         P         728
# 33335           134     קבוצת עמק איילון         P         728
# 33336           134     קבוצת עמק איילון         P         728
# 33337           134     קבוצת עמק איילון         P         728
#
#            tozeret_nm  degem_cd    degem_nm  shnat_yitzur   mehir  \
# 0      פולקסווגן גרמנ       612      2EE1H5          2016  288000
# 1      פולקסווגן גרמנ       635  7HC-7EB137          2016  322000
# 2      פולקסווגן גרמנ       646  7HC-SGBTF7          2016  400500
# 3      פולקסווגן גרמנ       649  7HC-SGJ1F7          2017  333800
# 4      פולקסווגן גרמנ       649  7HC-SGJ1F7          2016  347300
# ...               ...       ...         ...           ...     ...
# 33333      פורד ארה"ב       249         P8U          2022  250000
# 33334      פורד ארה"ב       262         P8T          2019  339500
# 33335      פורד ארה"ב       262         P8T          2020  339500
# 33336      פורד ארה"ב       262         P8T          2022  310000
# 33337      פורד ארה"ב       262         P8T          2021  310000
#
#       kinuy_mishari
# 0           CRAFTER
# 1       TRANSPORTER
# 2         CARAVELLE
# 3       TRANSPORTER
# 4       TRANSPORTER
# ...             ...
# 33333       MUSTANG
# 33334       MUSTANG
# 33335       MUSTANG
# 33336       MUSTANG
# 33337       MUSTANG
#
# [33338 rows x 10 columns]
#        semel_yevuan          shem_yevuan sug_degem  tozeret_cd  \
# 0               110  צ'מפיון מוטורס בע"מ         M         724
# 1               110  צ'מפיון מוטורס בע"מ         M         724
# 2               110  צ'מפיון מוטורס בע"מ         M         724
# 3               110  צ'מפיון מוטורס בע"מ         M         724
# 4               110  צ'מפיון מוטורס בע"מ         M         724
# ...             ...                  ...       ...         ...
# 33333           767          מיכאל ביטון         P         728
# 33334           134     קבוצת עמק איילון         P         728
# 33335           134     קבוצת עמק איילון         P         728
# 33336           134     קבוצת עמק איילון         P         728
# 33337           134     קבוצת עמק איילון         P         728
#
#            tozeret_nm  degem_cd    degem_nm  shnat_yitzur   mehir  \
# 0      פולקסווגן גרמנ       612      2EE1H5          2016  288000
# 1      פולקסווגן גרמנ       635  7HC-7EB137          2016  322000
# 2      פולקסווגן גרמנ       646  7HC-SGBTF7          2016  400500
# 3      פולקסווגן גרמנ       649  7HC-SGJ1F7          2017  333800
# 4      פולקסווגן גרמנ       649  7HC-SGJ1F7          2016  347300
# ...               ...       ...         ...           ...     ...
# 33333      פורד ארה"ב       249         P8U          2022  250000
# 33334      פורד ארה"ב       262         P8T          2019  339500
# 33335      פורד ארה"ב       262         P8T          2020  339500
# 33336      פורד ארה"ב       262         P8T          2022  310000
# 33337      פורד ארה"ב       262         P8T          2021  310000
#
#       kinuy_mishari
# 0           CRAFTER
# 1       TRANSPORTER
# 2         CARAVELLE
# 3       TRANSPORTER
# 4       TRANSPORTER
# ...             ...
# 33333       MUSTANG
# 33334       MUSTANG
# 33335       MUSTANG
# 33336       MUSTANG
# 33337       MUSTANG
#
# [33338 rows x 10 columns]

# %%
pd.set_option('float_format', '{:f}'.format)
data.describe(include = 'all')
# Out:
#         semel_yevuan          shem_yevuan sug_degem   tozeret_cd  \
# count   33338.000000                33338     33338 33338.000000
# unique           NaN                  384         2          NaN
# top              NaN  צ'מפיון מוטורס בע"מ         P          NaN
# freq             NaN                 4985     30623          NaN
# mean      224.629402                  NaN       NaN   589.891235
# std       180.823624                  NaN       NaN   295.290148
# min       102.000000                  NaN       NaN    11.000000
# 25%       110.000000                  NaN       NaN   404.000000
# 50%       130.000000                  NaN       NaN   624.000000
# 75%       242.000000                  NaN       NaN   787.000000
# max       878.000000                  NaN       NaN  1394.000000
#
#             tozeret_nm     degem_cd degem_nm  shnat_yitzur          mehir  \
# count            33338 33338.000000    33338  33338.000000   33338.000000
# unique             183          NaN     3671           NaN            NaN
# top     מרצדס בנץ גרמנ          NaN     3E7E           NaN            NaN
# freq              4005          NaN      361           NaN            NaN
# mean               NaN   457.740986      NaN   2019.049403  355786.207181
# std                NaN   594.228398      NaN      1.962770  290976.747442
# min                NaN     1.000000      NaN   2016.000000   40000.000000
# 25%                NaN    78.000000      NaN   2017.000000  168900.000000
# 50%                NaN   209.000000      NaN   2019.000000  276900.000000
# 75%                NaN   605.000000      NaN   2021.000000  429000.000000
# max                NaN  3091.000000      NaN   2022.000000 6202001.000000
#
#        kinuy_mishari
# count          33338
# unique          1840
# top          MODEL 3
# freq             571
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
#         semel_yevuan          shem_yevuan sug_degem   tozeret_cd  \
# count   33338.000000                33338     33338 33338.000000
# unique           NaN                  384         2          NaN
# top              NaN  צ'מפיון מוטורס בע"מ         P          NaN
# freq             NaN                 4985     30623          NaN
# mean      224.629402                  NaN       NaN   589.891235
# std       180.823624                  NaN       NaN   295.290148
# min       102.000000                  NaN       NaN    11.000000
# 25%       110.000000                  NaN       NaN   404.000000
# 50%       130.000000                  NaN       NaN   624.000000
# 75%       242.000000                  NaN       NaN   787.000000
# max       878.000000                  NaN       NaN  1394.000000
#
#             tozeret_nm     degem_cd degem_nm  shnat_yitzur          mehir  \
# count            33338 33338.000000    33338  33338.000000   33338.000000
# unique             183          NaN     3671           NaN            NaN
# top     מרצדס בנץ גרמנ          NaN     3E7E           NaN            NaN
# freq              4005          NaN      361           NaN            NaN
# mean               NaN   457.740986      NaN   2019.049403  355786.207181
# std                NaN   594.228398      NaN      1.962770  290976.747442
# min                NaN     1.000000      NaN   2016.000000   40000.000000
# 25%                NaN    78.000000      NaN   2017.000000  168900.000000
# 50%                NaN   209.000000      NaN   2019.000000  276900.000000
# 75%                NaN   605.000000      NaN   2021.000000  429000.000000
# max                NaN  3091.000000      NaN   2022.000000 6202001.000000
#
#        kinuy_mishari
# count          33338
# unique          1840
# top          MODEL 3
# freq             571
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
#Check if there are missing values in the data.
pd.isnull(data).sum()
# Out:
# semel_yevuan     0
# shem_yevuan      0
# sug_degem        0
# tozeret_cd       0
# tozeret_nm       0
# degem_cd         0
# degem_nm         0
# shnat_yitzur     0
# mehir            0
# kinuy_mishari    0
# dtype: int64
# semel_yevuan     0
# shem_yevuan      0
# sug_degem        0
# tozeret_cd       0
# tozeret_nm       0
# degem_cd         0
# degem_nm         0
# shnat_yitzur     0
# mehir            0
# kinuy_mishari    0
# dtype: int64

# %%
#Check correlation
data.corr()
# Out:
#               semel_yevuan  tozeret_cd  degem_cd  shnat_yitzur    mehir
# semel_yevuan      1.000000    0.156793  0.343361      0.456815 0.158780
# tozeret_cd        0.156793    1.000000 -0.126627      0.101962 0.030266
# degem_cd          0.343361   -0.126627  1.000000      0.290201 0.174119
# shnat_yitzur      0.456815    0.101962  0.290201      1.000000 0.110913
# mehir             0.158780    0.030266  0.174119      0.110913 1.000000
#               semel_yevuan  tozeret_cd  degem_cd  shnat_yitzur    mehir
# semel_yevuan      1.000000    0.156793  0.343361      0.456815 0.158780
# tozeret_cd        0.156793    1.000000 -0.126627      0.101962 0.030266
# degem_cd          0.343361   -0.126627  1.000000      0.290201 0.174119
# shnat_yitzur      0.456815    0.101962  0.290201      1.000000 0.110913
# mehir             0.158780    0.030266  0.174119      0.110913 1.000000

# %%
#Unnecessary data was removed. All cd columns removed since they are simply new names for the categorical data. They are not necessary.
data.drop(columns = ['semel_yevuan', 'tozeret_cd', 'degem_cd', 'kinuy_mishari'], axis = 1, inplace = True)
data
# Out:
#                shem_yevuan sug_degem      tozeret_nm    degem_nm  \
# 0      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...       ...             ...         ...
# 33333          מיכאל ביטון         P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון         P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון         P      פורד ארה"ב         P8T
# 33336     קבוצת עמק איילון         P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון         P      פורד ארה"ב         P8T
#
#        shnat_yitzur   mehir
# 0              2016  288000
# 1              2016  322000
# 2              2016  400500
# 3              2017  333800
# 4              2016  347300
# ...             ...     ...
# 33333          2022  250000
# 33334          2019  339500
# 33335          2020  339500
# 33336          2022  310000
# 33337          2021  310000
#
# [33338 rows x 6 columns]
#                shem_yevuan sug_degem      tozeret_nm    degem_nm  \
# 0      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ         M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...       ...             ...         ...
# 33333          מיכאל ביטון         P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון         P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון         P      פורד ארה"ב         P8T
# 33336     קבוצת עמק איילון         P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון         P      פורד ארה"ב         P8T
#
#        shnat_yitzur   mehir
# 0              2016  288000
# 1              2016  322000
# 2              2016  400500
# 3              2017  333800
# 4              2016  347300
# ...             ...     ...
# 33333          2022  250000
# 33334          2019  339500
# 33335          2020  339500
# 33336          2022  310000
# 33337          2021  310000
#
# [33338 rows x 6 columns]

# %%
#Renamed colums to make data-frame more readable.
data.rename(columns = {"shem_yevuan" : "Importer_name",
                       'sug_degem' : 'Model_type',
                       'tozeret_nm' : 'Company_name',
                       'degem_nm' : 'Model_name',
                       'shnat_yitzur': 'Construction_year',
                       'mehir': 'Price'}, inplace = True)
data
# Out:
#              Importer_name Model_type    Company_name  Model_name  \
# 0      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33333          מיכאל ביטון          P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33336     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון          P      פורד ארה"ב         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33333               2022  250000
# 33334               2019  339500
# 33335               2020  339500
# 33336               2022  310000
# 33337               2021  310000
#
# [33338 rows x 6 columns]
#              Importer_name Model_type    Company_name  Model_name  \
# 0      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33333          מיכאל ביטון          P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33336     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון          P      פורד ארה"ב         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33333               2022  250000
# 33334               2019  339500
# 33335               2020  339500
# 33336               2022  310000
# 33337               2021  310000
#
# [33338 rows x 6 columns]

# %%
data.describe(include = 'all')
# Out:
#               Importer_name Model_type    Company_name Model_name  \
# count                 33338      33338           33338      33338
# unique                  384          2             183       3671
# top     צ'מפיון מוטורס בע"מ          P  מרצדס בנץ גרמנ       3E7E
# freq                   4985      30623            4005        361
# mean                    NaN        NaN             NaN        NaN
# std                     NaN        NaN             NaN        NaN
# min                     NaN        NaN             NaN        NaN
# 25%                     NaN        NaN             NaN        NaN
# 50%                     NaN        NaN             NaN        NaN
# 75%                     NaN        NaN             NaN        NaN
# max                     NaN        NaN             NaN        NaN
#
#         Construction_year          Price
# count        33338.000000   33338.000000
# unique                NaN            NaN
# top                   NaN            NaN
# freq                  NaN            NaN
# mean          2019.049403  355786.207181
# std              1.962770  290976.747442
# min           2016.000000   40000.000000
# 25%           2017.000000  168900.000000
# 50%           2019.000000  276900.000000
# 75%           2021.000000  429000.000000
# max           2022.000000 6202001.000000
#               Importer_name Model_type    Company_name Model_name  \
# count                 33338      33338           33338      33338
# unique                  384          2             183       3671
# top     צ'מפיון מוטורס בע"מ          P  מרצדס בנץ גרמנ       3E7E
# freq                   4985      30623            4005        361
# mean                    NaN        NaN             NaN        NaN
# std                     NaN        NaN             NaN        NaN
# min                     NaN        NaN             NaN        NaN
# 25%                     NaN        NaN             NaN        NaN
# 50%                     NaN        NaN             NaN        NaN
# 75%                     NaN        NaN             NaN        NaN
# max                     NaN        NaN             NaN        NaN
#
#         Construction_year          Price
# count        33338.000000   33338.000000
# unique                NaN            NaN
# top                   NaN            NaN
# freq                  NaN            NaN
# mean          2019.049403  355786.207181
# std              1.962770  290976.747442
# min           2016.000000   40000.000000
# 25%           2017.000000  168900.000000
# 50%           2019.000000  276900.000000
# 75%           2021.000000  429000.000000
# max           2022.000000 6202001.000000

# %%
from sklearn.preprocessing import LabelEncoder

#Using label_encoder on all categorical data to make categorical data numerical instead, for the model to understand.
#New columns of the encoded data were added to the beginning of the DF.
data.insert(loc=0, column='Model_name_encoded', value=LabelEncoder().fit_transform(data['Model_name']))
data.insert(loc=0, column='Company_name_encoded', value=LabelEncoder().fit_transform(data['Company_name']))
data.insert(loc=0, column='Model_type_encoded', value=LabelEncoder().fit_transform(data['Model_type']))
data.insert(loc=0, column='Importer_name_encoded', value=LabelEncoder().fit_transform(data['Importer_name']))
data
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded        Importer_name Model_type    Company_name  \
# 0                     454  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 1                     994  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 2                    1003  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 3                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 4                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# ...                   ...                  ...        ...             ...
# 33333                3074          מיכאל ביטון          P      פורד ארה"ב
# 33334                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33335                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33336                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33337                3073     קבוצת עמק איילון          P      פורד ארה"ב
#
#        Model_name  Construction_year   Price
# 0          2EE1H5               2016  288000
# 1      7HC-7EB137               2016  322000
# 2      7HC-SGBTF7               2016  400500
# 3      7HC-SGJ1F7               2017  333800
# 4      7HC-SGJ1F7               2016  347300
# ...           ...                ...     ...
# 33333         P8U               2022  250000
# 33334         P8T               2019  339500
# 33335         P8T               2020  339500
# 33336         P8T               2022  310000
# 33337         P8T               2021  310000
#
# [33338 rows x 10 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded        Importer_name Model_type    Company_name  \
# 0                     454  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 1                     994  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 2                    1003  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 3                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 4                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# ...                   ...                  ...        ...             ...
# 33333                3074          מיכאל ביטון          P      פורד ארה"ב
# 33334                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33335                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33336                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33337                3073     קבוצת עמק איילון          P      פורד ארה"ב
#
#        Model_name  Construction_year   Price
# 0          2EE1H5               2016  288000
# 1      7HC-7EB137               2016  322000
# 2      7HC-SGBTF7               2016  400500
# 3      7HC-SGJ1F7               2017  333800
# 4      7HC-SGJ1F7               2016  347300
# ...           ...                ...     ...
# 33333         P8U               2022  250000
# 33334         P8T               2019  339500
# 33335         P8T               2020  339500
# 33336         P8T               2022  310000
# 33337         P8T               2021  310000
#
# [33338 rows x 10 columns]

# %%
#Copied data to new variable. From here we work with the encoded data.
data_encoded = data.copy()
data_encoded
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded        Importer_name Model_type    Company_name  \
# 0                     454  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 1                     994  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 2                    1003  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 3                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 4                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# ...                   ...                  ...        ...             ...
# 33333                3074          מיכאל ביטון          P      פורד ארה"ב
# 33334                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33335                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33336                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33337                3073     קבוצת עמק איילון          P      פורד ארה"ב
#
#        Model_name  Construction_year   Price
# 0          2EE1H5               2016  288000
# 1      7HC-7EB137               2016  322000
# 2      7HC-SGBTF7               2016  400500
# 3      7HC-SGJ1F7               2017  333800
# 4      7HC-SGJ1F7               2016  347300
# ...           ...                ...     ...
# 33333         P8U               2022  250000
# 33334         P8T               2019  339500
# 33335         P8T               2020  339500
# 33336         P8T               2022  310000
# 33337         P8T               2021  310000
#
# [33338 rows x 10 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded        Importer_name Model_type    Company_name  \
# 0                     454  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 1                     994  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 2                    1003  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 3                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 4                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# ...                   ...                  ...        ...             ...
# 33333                3074          מיכאל ביטון          P      פורד ארה"ב
# 33334                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33335                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33336                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33337                3073     קבוצת עמק איילון          P      פורד ארה"ב
#
#        Model_name  Construction_year   Price
# 0          2EE1H5               2016  288000
# 1      7HC-7EB137               2016  322000
# 2      7HC-SGBTF7               2016  400500
# 3      7HC-SGJ1F7               2017  333800
# 4      7HC-SGJ1F7               2016  347300
# ...           ...                ...     ...
# 33333         P8U               2022  250000
# 33334         P8T               2019  339500
# 33335         P8T               2020  339500
# 33336         P8T               2022  310000
# 33337         P8T               2021  310000
#
# [33338 rows x 10 columns]

# %%
#Categorical columns before encoding were removed
data_encoded.drop(columns = ['Importer_name','Model_type','Company_name','Model_name'], inplace = True)
data_encoded
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33333                3074               2022  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33336                3073               2022  310000
# 33337                3073               2021  310000
#
# [33338 rows x 6 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33333                3074               2022  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33336                3073               2022  310000
# 33337                3073               2021  310000
#
# [33338 rows x 6 columns]

# %%
#No data is categorical now.
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33338 entries, 0 to 33337
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Importer_name_encoded  33338 non-null  int32
#  1   Model_type_encoded     33338 non-null  int32
#  2   Company_name_encoded   33338 non-null  int32
#  3   Model_name_encoded     33338 non-null  int32
#  4   Construction_year      33338 non-null  int64
#  5   Price                  33338 non-null  int64
# dtypes: int32(4), int64(2)
# memory usage: 1.0 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33338 entries, 0 to 33337
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Importer_name_encoded  33338 non-null  int32
#  1   Model_type_encoded     33338 non-null  int32
#  2   Company_name_encoded   33338 non-null  int32
#  3   Model_name_encoded     33338 non-null  int32
#  4   Construction_year      33338 non-null  int64
#  5   Price                  33338 non-null  int64
# dtypes: int32(4), int64(2)
# memory usage: 1.0 MB

# %% [markdown]
# # Graphs and group-by's to further understand the data

# %%
fig=plt.figure()
plt.rcParams['figure.figsize'] = [21, 10]

# %%
plt.scatter(data_encoded['Importer_name_encoded'], data_encoded['Price'])
plt.title("Individual Car Price in Relation to Importer Name", fontsize = 30)
plt.xlabel("Importer name(encoded)", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
plt.show()

# %%
plt.scatter(data_encoded['Company_name_encoded'], data_encoded['Price'])
plt.title("Individual Car Price in Relation to Company Name", fontsize = 30)
plt.xlabel("Company name(encoded)", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
plt.show()

# %%
plt.scatter(data_encoded['Construction_year'], data_encoded['Price'])
plt.title("Individual Car Price in Relation to Construction Year", fontsize = 30)
plt.xlabel("Construction year", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
plt.show()

# %%
group_db_1 = data_encoded.groupby(['Company_name_encoded', 'Construction_year'], as_index = False).sum()
group_db_1
# Out:
#      Company_name_encoded  Construction_year  Importer_name_encoded  \
# 0                       0               2016                  57600
# 1                       0               2017                  83520
# 2                       0               2018                  38720
# 3                       0               2019                  31252
# 4                       0               2020                  28122
# ..                    ...                ...                    ...
# 917                   182               2016                   6016
# 918                   182               2017                   2632
# 919                   182               2018                   2444
# 920                   182               2019                    564
# 921                   182               2020                    376
#
#      Model_type_encoded  Model_name_encoded      Price
# 0                   179              209952   73515600
# 1                   261              335335  111478255
# 2                   121              165886   47357627
# 3                    98              128199   38106300
# 4                    88              113475   34715500
# ..                  ...                 ...        ...
# 917                  32               31250    6784800
# 918                  14                8769    3172600
# 919                  13                4623    3038510
# 920                   3                 147     749970
# 921                   2                  98     489980
#
# [922 rows x 6 columns]
#      Company_name_encoded  Construction_year  Importer_name_encoded  \
# 0                       0               2016                  57600
# 1                       0               2017                  83520
# 2                       0               2018                  38720
# 3                       0               2019                  31252
# 4                       0               2020                  28122
# ..                    ...                ...                    ...
# 917                   182               2016                   6016
# 918                   182               2017                   2632
# 919                   182               2018                   2444
# 920                   182               2019                    564
# 921                   182               2020                    376
#
#      Model_type_encoded  Model_name_encoded      Price
# 0                   179              209952   73515600
# 1                   261              335335  111478255
# 2                   121              165886   47357627
# 3                    98              128199   38106300
# 4                    88              113475   34715500
# ..                  ...                 ...        ...
# 917                  32               31250    6784800
# 918                  14                8769    3172600
# 919                  13                4623    3038510
# 920                   3                 147     749970
# 921                   2                  98     489980
#
# [922 rows x 6 columns]

# %%
group_db_2 = data_encoded.groupby(['Construction_year'], as_index = False).sum()
group_db_2
# Out:
#    Construction_year  Importer_name_encoded  Model_type_encoded  \
# 0               2016                1053708                4169
# 1               2017                1115730                4256
# 2               2018                 953633                3875
# 3               2019                 922470                3889
# 4               2020                1006350                4484
# 5               2021                1414477                6771
# 6               2022                 674715                3179
#
#    Company_name_encoded  Model_name_encoded       Price
# 0                440036             7913459  1386490223
# 1                435022             7938302  1531378649
# 2                400797             7881818  1463060218
# 3                386242             8288481  1518705797
# 4                457452             9599536  1870865917
# 5                646472            12096646  2759982178
# 6                289562             5667487  1330717593
#    Construction_year  Importer_name_encoded  Model_type_encoded  \
# 0               2016                1053708                4169
# 1               2017                1115730                4256
# 2               2018                 953633                3875
# 3               2019                 922470                3889
# 4               2020                1006350                4484
# 5               2021                1414477                6771
# 6               2022                 674715                3179
#
#    Company_name_encoded  Model_name_encoded       Price
# 0                440036             7913459  1386490223
# 1                435022             7938302  1531378649
# 2                400797             7881818  1463060218
# 3                386242             8288481  1518705797
# 4                457452             9599536  1870865917
# 5                646472            12096646  2759982178
# 6                289562             5667487  1330717593

# %%
plt.bar(group_db_1['Company_name_encoded'], group_db_1['Price'])
plt.title("Sum of Car Prices in Relation to Company Name", fontsize = 30)
plt.xlabel("Company name(encoded)", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
# Out:
# Text(0, 0.5, 'Price')
# Text(0, 0.5, 'Price')

# %%
plt.bar(group_db_2['Construction_year'], group_db_2['Price'])
plt.title("Sum of Car Prices in Relation to Construction Year", fontsize = 30)
plt.xlabel("Construction Year", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
# Out:
# Text(0, 0.5, 'Price')
# Text(0, 0.5, 'Price')

# %%
#Decided to remove 2022 data since it's new and fresh and not fully collected as of this time.
data_encoded_without_2022 = data_encoded[data_encoded.Construction_year != 2022]
data_encoded_without_2022
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33331                    227                   1                   140
# 33332                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33331                3073               2021  220000
# 33332                3074               2021  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33337                3073               2021  310000
#
# [29996 rows x 6 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33331                    227                   1                   140
# 33332                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33331                3073               2021  220000
# 33332                3074               2021  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33337                3073               2021  310000
#
# [29996 rows x 6 columns]

# %%
data_encoded_without_2022.describe(include = 'all')
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# count           29996.000000        29996.000000          29996.000000
# mean              215.574343            0.914922             92.212995
# std                90.035328            0.279002             53.330393
# min                 0.000000            0.000000              0.000000
# 25%               137.000000            1.000000             52.000000
# 50%               220.000000            1.000000             93.000000
# 75%               320.000000            1.000000            133.000000
# max               381.000000            1.000000            182.000000
#
#        Model_name_encoded  Construction_year          Price
# count        29996.000000       29996.000000   29996.000000
# mean          1790.846846        2018.720663  351062.907788
# std           1122.501444           1.789865  291543.913457
# min              0.000000        2016.000000   40000.000000
# 25%            720.000000        2017.000000  164990.000000
# 50%           1806.000000        2019.000000  269500.000000
# 75%           2722.000000        2020.000000  420600.000000
# max           3670.000000        2021.000000 6202001.000000
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# count           29996.000000        29996.000000          29996.000000
# mean              215.574343            0.914922             92.212995
# std                90.035328            0.279002             53.330393
# min                 0.000000            0.000000              0.000000
# 25%               137.000000            1.000000             52.000000
# 50%               220.000000            1.000000             93.000000
# 75%               320.000000            1.000000            133.000000
# max               381.000000            1.000000            182.000000
#
#        Model_name_encoded  Construction_year          Price
# count        29996.000000       29996.000000   29996.000000
# mean          1790.846846        2018.720663  351062.907788
# std           1122.501444           1.789865  291543.913457
# min              0.000000        2016.000000   40000.000000
# 25%            720.000000        2017.000000  164990.000000
# 50%           1806.000000        2019.000000  269500.000000
# 75%           2722.000000        2020.000000  420600.000000
# max           3670.000000        2021.000000 6202001.000000

# %%
from sklearn.preprocessing import StandardScaler

#Scaling the data
data_encoded_without_2022_scaled = StandardScaler().fit_transform(data_encoded_without_2022.to_numpy())
data_encoded_without_2022_scaled = pd.DataFrame(data_encoded_without_2022_scaled, columns = data_encoded_without_2022.columns)
data_encoded_without_2022_scaled.head()
# Out:
#    Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0               1.159849           -3.279317              0.764811
# 1               1.159849           -3.279317              0.764811
# 2               1.159849           -3.279317              0.764811
# 3               1.159849           -3.279317              0.764811
# 4               1.159849           -3.279317              0.764811
#
#    Model_name_encoded  Construction_year     Price
# 0           -1.190973          -1.520064 -0.216310
# 1           -0.709897          -1.520064 -0.099688
# 2           -0.701879          -1.520064  0.169573
# 3           -0.695643          -0.961353 -0.059213
# 4           -0.695643          -1.520064 -0.012907
#    Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0               1.159849           -3.279317              0.764811
# 1               1.159849           -3.279317              0.764811
# 2               1.159849           -3.279317              0.764811
# 3               1.159849           -3.279317              0.764811
# 4               1.159849           -3.279317              0.764811
#
#    Model_name_encoded  Construction_year     Price
# 0           -1.190973          -1.520064 -0.216310
# 1           -0.709897          -1.520064 -0.099688
# 2           -0.701879          -1.520064  0.169573
# 3           -0.695643          -0.961353 -0.059213
# 4           -0.695643          -1.520064 -0.012907

# %% [markdown]
# # Selecting a proper model for the data

# %%
from sklearn.model_selection import *
from sklearn.feature_selection import *
import random

X = data_encoded_without_2022_scaled[['Importer_name_encoded','Model_type_encoded','Company_name_encoded','Model_name_encoded', 'Construction_year']]
y = data_encoded_without_2022_scaled['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=random.randrange(1, 101))

# %%
#Training function. Includes regular training and cross-validation.
def train_and_evaluate(clf, X_train, y_train):
    rand = random.randrange(1, 101)
    clf.fit(X_train, y_train)
    scores_list = []
    print ("Coefficient of determination on training set:",clf.score(X_train, y_train))
    
    # create a k-fold cross validation iterator of k=10 folds
    cv = KFold(10 ,shuffle=True, random_state=rand)
    scores = cross_val_score(clf, X_train, y_train, cv=cv)
    scores_test = cross_val_score(clf, X_test, y_test, cv=cv)
    print("List of different scores: ",scores)
    print ("Average coefficient of determination using 10-fold crossvalidation:",np.mean(scores))
    print ("Average coefficient of determination using 10-fold crossvalidation(test):",np.mean(scores_test))
    scores_list.append(np.mean(scores))
    scores_list.append(np.mean(scores_test))
    return scores_list

# %% [markdown]
# # Linear regression attempt

# %%
from sklearn import linear_model

clf_sgd = linear_model.SGDRegressor(loss='squared_loss', penalty='l1',  random_state=random.randrange(1, 101))
train_and_evaluate(clf_sgd,X_train,y_train)

print("Linear regression coefficients:",clf_sgd.coef_)
# Out:
# Coefficient of determination on training set: 0.09437987401450687
# Coefficient of determination on training set: 0.09437987401450687
# List of different scores:  [0.09679202 0.11231624 0.0612692  0.08733458 0.07178319 0.09886475
#  0.10274709 0.09139583 0.08775946 0.1150825 ]
# Average coefficient of determination using 10-fold crossvalidation: 0.09253448575517018
# Average coefficient of determination using 10-fold crossvalidation(test): 0.0920479835684003
# Linear regression coefficients: [-0.21146713  0.04667633 -0.03756736 -0.18899606  0.07310804]
# List of different scores:  [0.09679202 0.11231624 0.0612692  0.08733458 0.07178319 0.09886475
#  0.10274709 0.09139583 0.08775946 0.1150825 ]
# Average coefficient of determination using 10-fold crossvalidation: 0.09253448575517018
# Average coefficient of determination using 10-fold crossvalidation(test): 0.0920479835684003
# Linear regression coefficients: [-0.21146713  0.04667633 -0.03756736 -0.18899606  0.07310804]

# %%
#Ridge regression. No noticable change.
clf_ridge = linear_model.Ridge()
train_and_evaluate(clf_ridge,X_train,y_train)
# Out:
# Coefficient of determination on training set: 0.09498652351789627
# List of different scores:  [0.08919111 0.1132881  0.08611127 0.11142497 0.09332994 0.08380802
#  0.07395512 0.09699943 0.09585377 0.10345979]
# Average coefficient of determination using 10-fold crossvalidation: 0.09474215088176621
# Average coefficient of determination using 10-fold crossvalidation(test): 0.09287583203441147
# [0.09474215088176621, 0.09287583203441147]
# Coefficient of determination on training set: 0.09498652351789627
# List of different scores:  [0.08919111 0.1132881  0.08611127 0.11142497 0.09332994 0.08380802
#  0.07395512 0.09699943 0.09585377 0.10345979]
# Average coefficient of determination using 10-fold crossvalidation: 0.09474215088176621
# Average coefficient of determination using 10-fold crossvalidation(test): 0.09287583203441147
# [0.09474215088176621, 0.09287583203441147]

# %% [markdown]
# # Random forest regression.

# %%
# Random forest regressor works here, Linear regression doesn't evaluate the data well.
from sklearn import ensemble
rand = random.randrange(1, 101)
cross_validation_average_scores = {}
cross_validation_average_scores_test = {}
for i in range(1,200, 24):
    print("Number of estimators:",i)
    clf_et=ensemble.ExtraTreesRegressor(n_estimators=i,random_state=rand)
    train_scores = train_and_evaluate(clf_et,X_train,y_train)
    cross_validation_average_scores[i] = train_scores[0]
    cross_validation_average_scores_test[i] = train_scores[1]

    print("")
    
train_max = max(cross_validation_average_scores, key=cross_validation_average_scores.get)
test_max = max(cross_validation_average_scores_test, key=cross_validation_average_scores_test.get)
print("The biggest average train cross-validation score: " + str(cross_validation_average_scores[train_max]) + " (" +str(train_max) + ")")
print("The biggest average test cross-validation score: " + str(cross_validation_average_scores_test[test_max]) + " (" +str(test_max) + ")")
# Out:
# Number of estimators: 1
# Coefficient of determination on training set: Number of estimators: 1
# Coefficient of determination on training set: 0.9851262720616353
# 0.9851262720616353
# List of different scores:  [0.89363429 0.84032714 0.86657015 0.86539726 0.83647875 0.88629178
#  0.90771049 0.86720536 0.89208469 0.84531133]
# Average coefficient of determination using 10-fold crossvalidation: 0.8701011247295198
# Average coefficient of determination using 10-fold crossvalidation(test): 0.5715756947483162
#
# Number of estimators: 25
# List of different scores:  [0.89363429 0.84032714 0.86657015 0.86539726 0.83647875 0.88629178
#  0.90771049 0.86720536 0.89208469 0.84531133]
# Average coefficient of determination using 10-fold crossvalidation: 0.8701011247295198
# Average coefficient of determination using 10-fold crossvalidation(test): 0.5715756947483162
#
# Number of estimators: 25
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.82937007 0.94131592 0.91192341 0.92551266 0.91193482 0.93722122
#  0.92330854 0.83208427 0.93975477 0.93571865]
# Average coefficient of determination using 10-fold crossvalidation: 0.9088144342442936
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7939118029407694
#
# Number of estimators: 49
# List of different scores:  [0.82937007 0.94131592 0.91192341 0.92551266 0.91193482 0.93722122
#  0.92330854 0.83208427 0.93975477 0.93571865]
# Average coefficient of determination using 10-fold crossvalidation: 0.9088144342442936
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7939118029407694
#
# Number of estimators: 49
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.93765001 0.92062609 0.91627204 0.89283874 0.91709176 0.94344641
#  0.83504254 0.93204919 0.83283481 0.93459505]
# Average coefficient of determination using 10-fold crossvalidation: 0.9062446658685864
# Average coefficient of determination using 10-fold crossvalidation(test): 0.791858631879268
#
# Number of estimators: 73
# List of different scores:  [0.93765001 0.92062609 0.91627204 0.89283874 0.91709176 0.94344641
#  0.83504254 0.93204919 0.83283481 0.93459505]
# Average coefficient of determination using 10-fold crossvalidation: 0.9062446658685864
# Average coefficient of determination using 10-fold crossvalidation(test): 0.791858631879268
#
# Number of estimators: 73
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.93484782 0.91650057 0.92810971 0.90867233 0.93635733 0.81521379
#  0.83349869 0.92675121 0.92575623 0.93049542]
# Average coefficient of determination using 10-fold crossvalidation: 0.9056203109930833
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7914601571240742
#
# Number of estimators: 97
# List of different scores:  [0.93484782 0.91650057 0.92810971 0.90867233 0.93635733 0.81521379
#  0.83349869 0.92675121 0.92575623 0.93049542]
# Average coefficient of determination using 10-fold crossvalidation: 0.9056203109930833
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7914601571240742
#
# Number of estimators: 97
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.94347977 0.93889063 0.89763275 0.80247285 0.84620837 0.94232612
#  0.93867599 0.92007569 0.92293431 0.93488244]
# Average coefficient of determination using 10-fold crossvalidation: 0.9087578915458021
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7819871680010027
#
# Number of estimators: 121
# List of different scores:  [0.94347977 0.93889063 0.89763275 0.80247285 0.84620837 0.94232612
#  0.93867599 0.92007569 0.92293431 0.93488244]
# Average coefficient of determination using 10-fold crossvalidation: 0.9087578915458021
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7819871680010027
#
# Number of estimators: 121
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.93475284 0.91928006 0.91382388 0.82233906 0.9305097  0.93703447
#  0.9131843  0.9223726  0.93211702 0.85400042]
# Average coefficient of determination using 10-fold crossvalidation: 0.9079414358215543
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7974084792200129
#
# Number of estimators: 145
# List of different scores:  [0.93475284 0.91928006 0.91382388 0.82233906 0.9305097  0.93703447
#  0.9131843  0.9223726  0.93211702 0.85400042]
# Average coefficient of determination using 10-fold crossvalidation: 0.9079414358215543
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7974084792200129
#
# Number of estimators: 145
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.93221018 0.93939941 0.91805845 0.80217827 0.82368568 0.9190392
#  0.92160026 0.91659937 0.93269109 0.93279263]
# Average coefficient of determination using 10-fold crossvalidation: 0.9038254547172828
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7836027119002804
#
# Number of estimators: 169
# List of different scores:  [0.93221018 0.93939941 0.91805845 0.80217827 0.82368568 0.9190392
#  0.92160026 0.91659937 0.93269109 0.93279263]
# Average coefficient of determination using 10-fold crossvalidation: 0.9038254547172828
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7836027119002804
#
# Number of estimators: 169
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.91821382 0.91698179 0.93762846 0.93027614 0.93537678 0.92646424
#  0.92701533 0.93528875 0.84251697 0.82020498]
# Average coefficient of determination using 10-fold crossvalidation: 0.9089967248649302
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7870131454152448
#
# Number of estimators: 193
# List of different scores:  [0.91821382 0.91698179 0.93762846 0.93027614 0.93537678 0.92646424
#  0.92701533 0.93528875 0.84251697 0.82020498]
# Average coefficient of determination using 10-fold crossvalidation: 0.9089967248649302
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7870131454152448
#
# Number of estimators: 193
# Coefficient of determination on training set: 0.9851262720616353
# Coefficient of determination on training set: 0.9851262720616353
# List of different scores:  [0.90827307 0.93455953 0.93292159 0.92214276 0.94157423 0.91533944
#  0.79388504 0.93252127 0.93880025 0.85037085]
# Average coefficient of determination using 10-fold crossvalidation: 0.9070388030569472
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7851724914862764
#
# The biggest average train cross-validation score: 0.9089967248649302 (169)
# The biggest average test cross-validation score: 0.7974084792200129 (121)
# List of different scores:  [0.90827307 0.93455953 0.93292159 0.92214276 0.94157423 0.91533944
#  0.79388504 0.93252127 0.93880025 0.85037085]
# Average coefficient of determination using 10-fold crossvalidation: 0.9070388030569472
# Average coefficient of determination using 10-fold crossvalidation(test): 0.7851724914862764
#
# The biggest average train cross-validation score: 0.9089967248649302 (169)
# The biggest average test cross-validation score: 0.7974084792200129 (121)

# %%
plt.bar(range(1,200, 24), cross_validation_average_scores, color = 'red')
plt.title("Average coefficient of determination using 10-fold crossvalidation", fontsize = 20)
plt.xlabel("Number of estimators", fontsize = 15)
plt.ylabel("Average coefficient of determination using 10-fold crossvalidation", fontsize = 15)
# Out:
# Text(0, 0.5, 'Average coefficient of determination using 10-fold crossvalidation')
# Text(0, 0.5, 'Average coefficient of determination using 10-fold crossvalidation')

# %%
plt.bar(range(1,200, 24), cross_validation_average_scores_test, color = 'red')
plt.title("Average coefficient of determination using 10-fold crossvalidation", fontsize = 20)
plt.xlabel("Number of estimators", fontsize = 15)
plt.ylabel("Average coefficient of determination using 10-fold crossvalidation", fontsize = 15)
# Out:
# Text(0, 0.5, 'Average coefficient of determination using 10-fold crossvalidation')
# Text(0, 0.5, 'Average coefficient of determination using 10-fold crossvalidation')

# %%
from sklearn import metrics
#Perfornamce fucntion. Uses test samples.
def measure_performance(X,y,clf,show_r2_score=False, show_mse_score=False):
    y_pred=clf.predict(X)   
    
    if show_r2_score:
        print ("Coefficient of determination(R2):{0:.3f}".format(metrics.r2_score(y,y_pred)))
    
    if show_mse_score:
        print("Coefficient of determination(MSE):" + str(metrics.mean_squared_error(y, y_pred)))
        
measure_performance(X_test,y_test,clf_et, show_r2_score=True, show_mse_score=True)
# Out:
# Coefficient of determination(R2):0.877
# Coefficient of determination(MSE):0.13597456964942695
# Coefficient of determination(R2):0.877
# Coefficient of determination(MSE):0.13597456964942695

# %% [markdown]
# # Semester 2 part

# %%
plt.style.use("seaborn")
#Get previous data after encoder from previous part and drop encoded columns
data
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded        Importer_name Model_type    Company_name  \
# 0                     454  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 1                     994  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 2                    1003  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 3                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 4                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# ...                   ...                  ...        ...             ...
# 33333                3074          מיכאל ביטון          P      פורד ארה"ב
# 33334                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33335                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33336                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33337                3073     קבוצת עמק איילון          P      פורד ארה"ב
#
#        Model_name  Construction_year   Price
# 0          2EE1H5               2016  288000
# 1      7HC-7EB137               2016  322000
# 2      7HC-SGBTF7               2016  400500
# 3      7HC-SGJ1F7               2017  333800
# 4      7HC-SGJ1F7               2016  347300
# ...           ...                ...     ...
# 33333         P8U               2022  250000
# 33334         P8T               2019  339500
# 33335         P8T               2020  339500
# 33336         P8T               2022  310000
# 33337         P8T               2021  310000
#
# [33338 rows x 10 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded        Importer_name Model_type    Company_name  \
# 0                     454  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 1                     994  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 2                    1003  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 3                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# 4                    1010  צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ
# ...                   ...                  ...        ...             ...
# 33333                3074          מיכאל ביטון          P      פורד ארה"ב
# 33334                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33335                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33336                3073     קבוצת עמק איילון          P      פורד ארה"ב
# 33337                3073     קבוצת עמק איילון          P      פורד ארה"ב
#
#        Model_name  Construction_year   Price
# 0          2EE1H5               2016  288000
# 1      7HC-7EB137               2016  322000
# 2      7HC-SGBTF7               2016  400500
# 3      7HC-SGJ1F7               2017  333800
# 4      7HC-SGJ1F7               2016  347300
# ...           ...                ...     ...
# 33333         P8U               2022  250000
# 33334         P8T               2019  339500
# 33335         P8T               2020  339500
# 33336         P8T               2022  310000
# 33337         P8T               2021  310000
#
# [33338 rows x 10 columns]

# %%
data_encoded
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33333                3074               2022  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33336                3073               2022  310000
# 33337                3073               2021  310000
#
# [33338 rows x 6 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33333                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33336                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33333                3074               2022  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33336                3073               2022  310000
# 33337                3073               2021  310000
#
# [33338 rows x 6 columns]

# %%
data_non_encoded = data.drop(columns = ['Importer_name_encoded','Model_type_encoded','Company_name_encoded','Model_name_encoded'])
data_non_encoded
# Out:
#              Importer_name Model_type    Company_name  Model_name  \
# 0      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33333          מיכאל ביטון          P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33336     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון          P      פורד ארה"ב         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33333               2022  250000
# 33334               2019  339500
# 33335               2020  339500
# 33336               2022  310000
# 33337               2021  310000
#
# [33338 rows x 6 columns]
#              Importer_name Model_type    Company_name  Model_name  \
# 0      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33333          מיכאל ביטון          P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33336     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון          P      פורד ארה"ב         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33333               2022  250000
# 33334               2019  339500
# 33335               2020  339500
# 33336               2022  310000
# 33337               2021  310000
#
# [33338 rows x 6 columns]

# %%
#Remove the 2022 cars since it isn't representative of that year
data_non_encoded = data_non_encoded[data_non_encoded.Construction_year != 2022]
data_encoded = data_encoded[data_encoded.Construction_year != 2022]

# %%
data_non_encoded
# Out:
#              Importer_name Model_type    Company_name  Model_name  \
# 0      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33331      לוי'ס קארס בע"מ          P      פורד ארה"ב         P8T
# 33332          מיכאל ביטון          P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון          P      פורד ארה"ב         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33331               2021  220000
# 33332               2021  250000
# 33334               2019  339500
# 33335               2020  339500
# 33337               2021  310000
#
# [29996 rows x 6 columns]
#              Importer_name Model_type    Company_name  Model_name  \
# 0      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ      2EE1H5
# 1      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-7EB137
# 2      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGBTF7
# 3      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# 4      צ'מפיון מוטורס בע"מ          M  פולקסווגן גרמנ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33331      לוי'ס קארס בע"מ          P      פורד ארה"ב         P8T
# 33332          מיכאל ביטון          P      פורד ארה"ב         P8U
# 33334     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33335     קבוצת עמק איילון          P      פורד ארה"ב         P8T
# 33337     קבוצת עמק איילון          P      פורד ארה"ב         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33331               2021  220000
# 33332               2021  250000
# 33334               2019  339500
# 33335               2020  339500
# 33337               2021  310000
#
# [29996 rows x 6 columns]

# %%
data_encoded
# Out:
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33331                    227                   1                   140
# 33332                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33331                3073               2021  220000
# 33332                3074               2021  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33337                3073               2021  310000
#
# [29996 rows x 6 columns]
#        Importer_name_encoded  Model_type_encoded  Company_name_encoded  \
# 0                        320                   0                   133
# 1                        320                   0                   133
# 2                        320                   0                   133
# 3                        320                   0                   133
# 4                        320                   0                   133
# ...                      ...                 ...                   ...
# 33331                    227                   1                   140
# 33332                    253                   1                   140
# 33334                    330                   1                   140
# 33335                    330                   1                   140
# 33337                    330                   1                   140
#
#        Model_name_encoded  Construction_year   Price
# 0                     454               2016  288000
# 1                     994               2016  322000
# 2                    1003               2016  400500
# 3                    1010               2017  333800
# 4                    1010               2016  347300
# ...                   ...                ...     ...
# 33331                3073               2021  220000
# 33332                3074               2021  250000
# 33334                3073               2019  339500
# 33335                3073               2020  339500
# 33337                3073               2021  310000
#
# [29996 rows x 6 columns]

# %%
data_encoded.nunique()
# Out:
# Importer_name_encoded     369
# Model_type_encoded          2
# Company_name_encoded      182
# Model_name_encoded       3594
# Construction_year           6
# Price                    3307
# dtype: int64
# Importer_name_encoded     369
# Model_type_encoded          2
# Company_name_encoded      182
# Model_name_encoded       3594
# Construction_year           6
# Price                    3307
# dtype: int64

# %%
data_reversed = data_non_encoded.loc[:,['Importer_name', 'Company_name']].applymap(lambda x: x[::-1]) 
data_reversed
# Out:
#              Importer_name    Company_name
# 0      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 1      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 2      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 3      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 4      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# ...                    ...             ...
# 33331      מ"עב סראק ס'יול      ב"הרא דרופ
# 33332          ןוטיב לאכימ      ב"הרא דרופ
# 33334     ןולייא קמע תצובק      ב"הרא דרופ
# 33335     ןולייא קמע תצובק      ב"הרא דרופ
# 33337     ןולייא קמע תצובק      ב"הרא דרופ
#
# [29996 rows x 2 columns]
#              Importer_name    Company_name
# 0      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 1      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 2      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 3      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# 4      מ"עב סרוטומ ןויפמ'צ  נמרג ןגווסקלופ
# ...                    ...             ...
# 33331      מ"עב סראק ס'יול      ב"הרא דרופ
# 33332          ןוטיב לאכימ      ב"הרא דרופ
# 33334     ןולייא קמע תצובק      ב"הרא דרופ
# 33335     ןולייא קמע תצובק      ב"הרא דרופ
# 33337     ןולייא קמע תצובק      ב"הרא דרופ
#
# [29996 rows x 2 columns]

# %%
data_reversed = pd.concat([data_reversed, data_non_encoded.loc[:,['Model_type','Model_name','Construction_year','Price']]], axis = 1)

# %%
"""
Data reversed will be used for plotting visually effective graphs.  
"""
data_reversed = data_reversed[['Importer_name','Model_type','Company_name','Model_name','Construction_year','Price']]
data_reversed
# Out:
#              Importer_name Model_type    Company_name  Model_name  \
# 0      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ      2EE1H5
# 1      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-7EB137
# 2      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-SGBTF7
# 3      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-SGJ1F7
# 4      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33331      מ"עב סראק ס'יול          P      ב"הרא דרופ         P8T
# 33332          ןוטיב לאכימ          P      ב"הרא דרופ         P8U
# 33334     ןולייא קמע תצובק          P      ב"הרא דרופ         P8T
# 33335     ןולייא קמע תצובק          P      ב"הרא דרופ         P8T
# 33337     ןולייא קמע תצובק          P      ב"הרא דרופ         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33331               2021  220000
# 33332               2021  250000
# 33334               2019  339500
# 33335               2020  339500
# 33337               2021  310000
#
# [29996 rows x 6 columns]
#              Importer_name Model_type    Company_name  Model_name  \
# 0      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ      2EE1H5
# 1      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-7EB137
# 2      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-SGBTF7
# 3      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-SGJ1F7
# 4      מ"עב סרוטומ ןויפמ'צ          M  נמרג ןגווסקלופ  7HC-SGJ1F7
# ...                    ...        ...             ...         ...
# 33331      מ"עב סראק ס'יול          P      ב"הרא דרופ         P8T
# 33332          ןוטיב לאכימ          P      ב"הרא דרופ         P8U
# 33334     ןולייא קמע תצובק          P      ב"הרא דרופ         P8T
# 33335     ןולייא קמע תצובק          P      ב"הרא דרופ         P8T
# 33337     ןולייא קמע תצובק          P      ב"הרא דרופ         P8T
#
#        Construction_year   Price
# 0                   2016  288000
# 1                   2016  322000
# 2                   2016  400500
# 3                   2017  333800
# 4                   2016  347300
# ...                  ...     ...
# 33331               2021  220000
# 33332               2021  250000
# 33334               2019  339500
# 33335               2020  339500
# 33337               2021  310000
#
# [29996 rows x 6 columns]

# %% [markdown]
# # Group-by's and visualization to understand the data better

# %%
#Function zone
COLOR = 'white'
FONT = 'Adobe'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
plt.rcParams['font.family'] = FONT
plt.rcParams['axes.facecolor'] = 'black'
plt.rcParams['figure.facecolor'] = 'black'



"""
Plots sum of car prices(color = Green)
"""
def plot_grouped_price_sum(DataFrame, columns, n, largest = True): 
    if(largest):
        Grouped_data = DataFrame.groupby(by = columns).Price.sum().nlargest(n = n)
        msg = "First"
    else:
        Grouped_data = DataFrame.groupby(by = columns).Price.sum().nsmallest(n = n)
        msg = "Last"
     
    
    X_string = ""
    for i in range(len(columns)):
        if(i == len(columns) - 1):
            X_string = X_string + columns[i]
        else:
            X_string = X_string + columns[i] + ", "
    plt.figure(facecolor='black') 
    Grouped_data.plot(kind = "bar", figsize = (24, 8), fontsize = 16, color = "Green")
    ax = plt.axes()
    ax.set_facecolor("black")
    
    plt.ylabel("Sum of car price", fontsize = 16)
    plt.xlabel(X_string, fontsize = 16)
    plt.title(msg+" {0}".format(n), fontsize = 18)
    plt.show()

    
"""
Plots mean of car prices(color = Purple)
"""
def plot_grouped_price_mean(DataFrame, columns, n, largest = True):
    if(largest):
        Grouped_data = DataFrame.groupby(by = columns).Price.mean().nlargest(n = n)
        msg = "First"
    else:
        Grouped_data = DataFrame.groupby(by = columns).Price.mean().nsmallest(n = n)
        msg = "Last"
    
    X_string = ""
    for i in range(len(columns)):
        if(i == len(columns) - 1):
            X_string = X_string + columns[i]
        else:
            X_string = X_string + columns[i] + ", "
    plt.figure(facecolor='black') 
    Grouped_data.plot(kind = "bar", figsize = (24, 8), fontsize = 16, color = "Purple")
    ax = plt.axes()
    ax.set_facecolor("black")
    
    plt.ylabel("Car price mean", fontsize = 16)
    plt.xlabel(X_string, fontsize = 16)
    plt.title(msg+" {0}".format(n), fontsize = 18)
    plt.show()
    
"""
Plots amount of cars(color = blue)
"""
def plot_grouped_car_count(DataFrame, columns, n, largest = True):
    if(largest):
        Grouped_data = DataFrame.groupby(by = columns).Price.count().nlargest(n = n)
        msg = "First"
    else:
        Grouped_data = DataFrame.groupby(by = columns).Price.count().nsmallest(n = n)
        msg = "Last"
    
    X_string = ""
    for i in range(len(columns)):
        if(i == len(columns) - 1):
            X_string = X_string + columns[i]
        else:
            X_string = X_string + columns[i] + ", "
    plt.figure(facecolor='black') 
    Grouped_data.plot(kind = "bar", figsize = (24, 8), fontsize = 16, color = "blue")
    ax = plt.axes()
    ax.set_facecolor("black")
    
    plt.ylabel("Car count", fontsize = 16)
    plt.xlabel(X_string, fontsize = 16)
    plt.title(msg+" {0}".format(n), fontsize = 18)
    plt.show()

# %%
plot_grouped_car_count(DataFrame = data_reversed, columns = ['Construction_year'], n = 40)
# Out:
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Adobe'] not found. Falling back to DejaVu Sans.

# %%
plot_grouped_car_count(DataFrame = data_reversed, columns = ['Importer_name','Construction_year'], n = 30)

# %%
plot_grouped_car_count(DataFrame = data_reversed, columns = ['Importer_name'], n = 30)

# %%
plot_grouped_car_count(DataFrame = data_reversed, columns = ['Company_name'], n = 30)

# %%
plot_grouped_car_count(DataFrame = data_reversed, columns = ['Company_name', 'Model_name'], n = 30)

# %%
plot_grouped_car_count(DataFrame = data_reversed, columns = ['Importer_name','Company_name','Model_name'], n = 40)

# %% [markdown]
# # Models

# %% [markdown]
# ## Dummy Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %%
X = data_encoded.drop("Price", axis = 1).values
y = data_encoded['Price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.dummy import DummyRegressor
dum = DummyRegressor(strategy="median")
dum.fit(X_train, y_train)
dum.score(X_test, y_test)
# Out:
# -0.0772483410498932
# -0.0772483410498932

# %% [markdown]
# ## Linear Regression

# %%
regressor = linear_model.LinearRegression()
regressor.fit(X_train, y_train)
predicted = regressor.predict(X_test)

print("Score on test: {}".format(regressor.score(X_test, y_test)))
print("Training set cv score (r2): {}".format(cross_val_score(regressor, X_train, y_train, cv=10, scoring='r2').mean()))
print("Test set cv score (r2): {}".format(cross_val_score(regressor, X_test, y_test, cv=10, scoring='r2').mean()))
# Out:
# Score on test: 0.099277860346068
# Training set cv score (r2): 0.09343427454366494
# Test set cv score (r2): 0.09812912835026341
# Score on test: 0.099277860346068
# Training set cv score (r2): 0.09343427454366494
# Test set cv score (r2): 0.09812912835026341

# %%
outcomes = [(i, y_test[i], predicted[i]) for i in range(len(y_test))]
outcomes_sorted = sorted(outcomes, key=lambda x:x[1])

df = pd.DataFrame({'Real': [outcomes_sorted[i][1] for i in range(0, len(y_test), int(len(y_test)/10))],
                   'Predicted': [outcomes_sorted[i][2] for i in range(0, len(y_test), int(len(y_test)/10))]})
df.plot(kind='bar', figsize = (24, 8), fontsize = 16)    
plt.title("Predicted price vs Real Price (specific samples)", fontsize = 18)

plt.show()

# %%
means_list = []
for i in range(10):
    sliced = outcomes_sorted[int(len(outcomes_sorted)/10)*(i):int(len(outcomes_sorted)/10)*(i+1)]
    real_sum = sum([sliced[i][1] for i in range(len(sliced))])/len(sliced)
    predicted_sum = sum([sliced[i][2] for i in range(len(sliced))])/len(sliced)
    means_list.append((real_sum, predicted_sum))

df = pd.DataFrame({'Real': [means_list[i][0] for i in range(10)],
                   'Predicted': [means_list[i][1] for i in range(10)]})
df.plot(kind='bar', figsize = (24, 8), fontsize = 16)    
plt.title("Predicted price vs Real Price (mean prices)", fontsize = 18)

plt.show()

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBRegressor
XGB = XGBRegressor()
XGB.fit(X_train, y_train)
print("Score on test: {}".format(XGB.score(X_test, y_test)))
print("Training set cv score (r2): {}".format(cross_val_score(XGB, X_train, y_train, cv=10, scoring='r2').mean()))
print("Test set cv score (r2): {}".format(cross_val_score(XGB, X_test, y_test, cv=10, scoring='r2').mean()))
# Out:
# Score on test: 0.8991635785855676
# Score on test: 0.8991635785855676
# Training set cv score (r2): 0.8758122102660991
# Training set cv score (r2): 0.8758122102660991
# Test set cv score (r2): 0.8545700148599904
# Test set cv score (r2): 0.8545700148599904

# %%
indexes = np.argsort(XGB.feature_importances_)
df = pd.DataFrame({"Features": data_encoded.columns[:-1], 
                  "importances" : XGB.feature_importances_[indexes]})
df = df.set_index("Features")
df.plot(kind='bar', figsize = (24, 8), fontsize = 16)    
plt.title("Feature Importances", fontsize = 18)

plt.show()

# %%
param_grid = {
    'n_estimators': [400],
    'colsample_bytree': [0.7, 0.8],
    'max_depth': [15,25],
    'reg_alpha': [1.1, 1.3],
    'reg_lambda': [1.1, 1.3],
    'subsample': [0.7, 0.9]
}
grid = GridSearchCV(estimator=XGB, param_grid=param_grid, n_jobs=4 cv=10, scoring='r2')
XGB_grid = grid.fit(X_train, y_train)
print(XGB_grid.best_score_)
print(XGB_grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\IDAN'S~1\AppData\Local\Temp/ipykernel_3200/1090856189.py in <module>
#       8 }
#       9 grid = GridSearchCV(estimator=XGB, param_grid=param_grid, cv=10, scoring='r2')
# ---> 10 XGB_grid = grid.fit(X_train, y_train)
#      11 print(XGB_grid.best_score_)
#      12 print(XGB_grid.best_params_)
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# D:\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# D:\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# D:\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# D:\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     787
#     788         model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# --> 789         self._Booster = train(
#     790             params,
#     791             train_dmatrix,
#
# D:\anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# D:\anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# D:\anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\IDAN'S~1\AppData\Local\Temp/ipykernel_3200/1090856189.py in <module>
#       8 }
#       9 grid = GridSearchCV(estimator=XGB, param_grid=param_grid, cv=10, scoring='r2')
# ---> 10 XGB_grid = grid.fit(X_train, y_train)
#      11 print(XGB_grid.best_score_)
#      12 print(XGB_grid.best_params_)
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# D:\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# D:\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# D:\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# D:\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# D:\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     787
#     788         model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# --> 789         self._Booster = train(
#     790             params,
#     791             train_dmatrix,
#
# D:\anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# D:\anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# D:\anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
from sklearn.pipeline import Pipeline

XGB_pipe = Pipeline(steps=[('Scaler', StandardScaler()), ('XGBoost', XGB)])
XGB_pipe.fit(X_train, y_train)
print("Score on test: {}".format(XGB_pipe.score(X_test, y_test)))
print("Test set cv score (r2): {}".format(cross_val_score(XGB_pipe, X_test, y_test, cv=10, scoring='r2').mean()))
# Out:
# Score on test: 0.8991685615236658
# Score on test: 0.8991685615236658
# Test set cv score (r2): 0.8548808569177913
# Test set cv score (r2): 0.8548808569177913

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
RFR_pipe = Pipeline(steps=[('Scaler', StandardScaler()), ('RandomForest', RandomForestRegressor(n_estimators = 500))])
RFR_pipe.fit(X_train, y_train)
print("Test set cv score (r2): {}".format(cross_val_score(RFR_pipe, X_test, y_test, cv=10, scoring='r2').mean()))
# Out:
# Test set cv score (r2): 0.8521432519765988
# Test set cv score (r2): 0.8521432519765988

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor
voter = VotingRegressor([('XGB', XGB_pipe),('RFR', RFR_pipe)])
voter.fit(X_train, y_train)
print("Test set cv score (r2): {}".format(cross_val_score(voter, X_test, y_test, cv=10, scoring='r2').mean()))
# Out:
# Test set cv score (r2): 0.8622500189903809
# Test set cv score (r2): 0.8622500189903809
