# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys, os
script_dir = sys.path[0]
print(script_dir)

data_path = os.path.join(script_dir+r'\train\train\7554\SimpleTest\1.csv')
print(data_path)
# Out:
# C:\Users\eliko\Desktop\Data_science_project\Project\data visualization project\pandas project
# C:\Users\eliko\Desktop\Data_science_project\Project\data visualization project\pandas project\train\train\7554\SimpleTest\1.csv

# %%
data = pd.read_csv(data_path)

# %%
data
# Out:
#                                                     X           Y   Pressure  \
# 0                                    925.902760133965  665.541979   0.045884
# 1                                    925.902760133965  665.541979   0.045884
# 2                                    926.692689687031  665.647303   0.082506
# 3                                    927.008661508257  665.647303   0.115953
# 4                                    927.324633329484  665.594641   0.140368
# ..                                                ...         ...        ...
# 129                                  584.863841090195  646.846980   0.386954
# 130                                  584.653193209377  646.741656   0.386954
# 131                                  584.653193209377  646.741656   0.389151
# 132  Time Elapsed till drawing started: 00:11.2234987         NaN        NaN
# 133   Time Elapsed till drawing submit: 00:17.1449348         NaN        NaN
#
#       TiltX   TiltY           Time
# ...

# %%
less_data = data.iloc[:-2,:]
less_data
# Out:
#                     X           Y   Pressure   TiltX   TiltY           Time
# 0    925.902760133965  665.541979   0.045884 -4917.0   669.0  00:12.6099853
# 1    925.902760133965  665.541979   0.045884 -4917.0   669.0  00:12.6256038
# 2    926.692689687031  665.647303   0.082506 -4917.0   669.0  00:12.6445684
# 3    927.008661508257  665.647303   0.115953 -4917.0   669.0  00:12.6602735
# 4    927.324633329484  665.594641   0.140368 -4917.0   669.0  00:12.6838147
# ..                ...         ...        ...     ...     ...            ...
# 127  585.495784732648  647.004966   0.378408 -4510.0  1946.0  00:14.0316787
# 128  584.863841090195  646.846980   0.382803 -4510.0  1946.0  00:14.0472865
# 129  584.863841090195  646.846980   0.386954 -4510.0  1946.0  00:14.0629098
# 130  584.653193209377  646.741656   0.386954 -4501.0  1991.0  00:14.0785335
# 131  584.653193209377  646.741656   0.389151 -4501.0  1991.0  00:14.0941464
#
# [132 rows x 6 columns]

# %%
print("Data columns:",less_data.columns)
print(less_data.info())
# Out:
# Data columns: Index(['X', ' Y', ' Pressure', ' TiltX', ' TiltY', ' Time'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   X          132 non-null    object
#  1    Y         132 non-null    float64
#  2    Pressure  132 non-null    float64
#  3    TiltX     132 non-null    float64
#  4    TiltY     132 non-null    float64
#  5    Time      132 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 6.3+ KB
# None

# %%
less_data = less_data.astype({'X' : float})
less_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   X          132 non-null    float64
#  1    Y         132 non-null    float64
#  2    Pressure  132 non-null    float64
#  3    TiltX     132 non-null    float64
#  4    TiltY     132 non-null    float64
#  5    Time      132 non-null    object
# dtypes: float64(5), object(1)
# memory usage: 6.3+ KB

# %%
less_data
# Out:
#               X           Y   Pressure   TiltX   TiltY           Time
# 0    925.902760  665.541979   0.045884 -4917.0   669.0  00:12.6099853
# 1    925.902760  665.541979   0.045884 -4917.0   669.0  00:12.6256038
# 2    926.692690  665.647303   0.082506 -4917.0   669.0  00:12.6445684
# 3    927.008662  665.647303   0.115953 -4917.0   669.0  00:12.6602735
# 4    927.324633  665.594641   0.140368 -4917.0   669.0  00:12.6838147
# ..          ...         ...        ...     ...     ...            ...
# 127  585.495785  647.004966   0.378408 -4510.0  1946.0  00:14.0316787
# 128  584.863841  646.846980   0.382803 -4510.0  1946.0  00:14.0472865
# 129  584.863841  646.846980   0.386954 -4510.0  1946.0  00:14.0629098
# 130  584.653193  646.741656   0.386954 -4501.0  1991.0  00:14.0785335
# 131  584.653193  646.741656   0.389151 -4501.0  1991.0  00:14.0941464
#
# [132 rows x 6 columns]

# %%
plt.scatter(less_data["X"], less_data[" Y"])
